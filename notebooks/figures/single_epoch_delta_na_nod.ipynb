# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
import pandas as pd

REPO_NAME = "cvpr_perturbations"
repo_root = None
cwd = Path.cwd().resolve()
for path in (cwd, *cwd.parents):
    if path.name == REPO_NAME:
        repo_root = path
        break
if repo_root is None:
    raise RuntimeError(
        f"Unable to locate '{REPO_NAME}' in the current working tree; adjust REPO_NAME or run from project root."
    )
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from notebooks.utils.single_epoch_dneural import plot_single_epoch_delta_neural_alignment

# %%
baseline_seed1_na_results = pd.read_csv('../../data/brain_rsa_results/baseline/baseline_seed1_brain_rsa_results.csv')

baseline_seed2_na_results = pd.read_csv('../../data/brain_rsa_results/baseline/baseline_seed2_brain_rsa_results.csv')

baseline_seed3_na_results = pd.read_csv('../../data/brain_rsa_results/baseline/baseline_seed3_brain_rsa_results.csv')

# %%
sweep_seed1_na_results = pd.read_csv('../../data/brain_rsa_results/single_epoch_sweep/sweep_seed42_brain_rsa_results.csv')

# %%
print(sweep_seed1_na_results.head())
# Out:
#    roi  epoch  training_run       rho  p_value
# 0  FFC      1             1  0.144219      0.0
# 1  FFC      2             1  0.118052      0.0
# 2  FFC      3             1  0.098283      0.0
# 3  FFC      4             1  0.078987      0.0
# 4  FFC      5             1  0.069166      0.0

# %%
plot_single_epoch_delta_neural_alignment(
    baseline_seed1_na_results,
    sweep_seed1_na_results,
    perturbed_runs_is_mapping=False,
    plot_rois=['FFC', 'PIT', 'LO1', 'LO2', 'LO3', 'V1', 'V2', 'V3']
)
# Out:
# (<Figure size 1600x600 with 8 Axes>,
#  {'FFC':           run_name  perturbation_epoch  delta_neural_alignment  \
#   0    training_run1                   1                0.009477
#   1    training_run2                   2                0.027089
#   2    training_run3                   3                0.044562
#   3    training_run4                   4                0.062549
#   4    training_run5                   5                0.065233
#   ..             ...                 ...                     ...
#   92  training_run94                  94               -0.055395
#   93  training_run95                  95               -0.055126
#   94  training_run96                  96               -0.042650
#   95  training_run97                  97               -0.052014
#   96  training_run98                  98               -0.051874
#
#       perturbed_neural_alignment  baseline_neural_alignment
#   0                     0.144219                   0.134742
#   1                     0.113982                   0.086893
#   2                     0.121002                   0.076440
#   3                     0.132201                   0.069653
#   4                     0.134954                   0.069721
#   ..                         ...                        ...
#   92                    0.079251                   0.134646
#   93                    0.079751                   0.134877
#   94                    0.092286                   0.134936
#   95                    0.083936                   0.135950
#   96                    0.083949                   0.135822
#
#   [97 rows x 5 columns],
#   'PIT':           run_name  perturbation_epoch  delta_neural_alignment  \
#   0    training_run1                   1                0.006891
#   1    training_run2                   2                0.023431
#   2    training_run3                   3                0.038009
#   3    training_run4                   4                0.056478
#   4    training_run5                   5                0.055226
#   ..             ...                 ...                     ...
#   92  training_run94                  94               -0.029942
#   93  training_run95                  95               -0.028770
#   94  training_run96                  96               -0.021759
#   95  training_run97                  97               -0.028711
#   96  training_run98                  98               -0.024978
#
#       perturbed_neural_alignment  baseline_neural_alignment
#   0                     0.102322                   0.095431
#   1                     0.075569                   0.052138
#   2                     0.078773                   0.040763
#   3                     0.090414                   0.033937
#   4                     0.091684                   0.036458
#   ..                         ...                        ...
#   92                    0.063903                   0.093845
#   93                    0.065559                   0.094329
#   94                    0.071900                   0.093660
#   95                    0.066442                   0.095154
#   96                    0.069868                   0.094845
#
#   [97 rows x 5 columns],
#   'LO1':           run_name  perturbation_epoch  delta_neural_alignment  \
#   0    training_run1                   1                0.000170
#   1    training_run2                   2                0.009354
#   2    training_run3                   3                0.012223
#   3    training_run4                   4                0.016648
#   4    training_run5                   5                0.010555
#   ..             ...                 ...                     ...
#   92  training_run94                  94               -0.061242
#   93  training_run95                  95               -0.060886
#   94  training_run96                  96               -0.049403
#   95  training_run97                  97               -0.057128
#   96  training_run98                  98               -0.057458
#
#       perturbed_neural_alignment  baseline_neural_alignment
#   0                     0.036300                   0.036130
#   1                     0.020171                   0.010817
#   2                     0.027205                   0.014982
#   3                     0.035454                   0.018806
#   4                     0.034930                   0.024374
#   ..                         ...                        ...
#   92                    0.007607                   0.068849
#   93                    0.007809                   0.068695
#   94                    0.019303                   0.068706
#   95                    0.010960                   0.068088
#   96                    0.011456                   0.068914
#
#   [97 rows x 5 columns],
#   'LO2':           run_name  perturbation_epoch  delta_neural_alignment  \
#   0    training_run1                   1                0.013137
#   1    training_run2                   2                0.031008
#   2    training_run3                   3                0.055737
#   3    training_run4                   4                0.078524
#   4    training_run5                   5                0.075359
#   ..             ...                 ...                     ...
#   92  training_run94                  94               -0.057617
#   93  training_run95                  95               -0.054614
#   94  training_run96                  96               -0.041868
#   95  training_run97                  97               -0.053322
#   96  training_run98                  98               -0.047785
#
#       perturbed_neural_alignment  baseline_neural_alignment
#   0                     0.151296                   0.138159
#   1                     0.101169                   0.070161
#   2                     0.108905                   0.053169
#   3                     0.123505                   0.044981
#   4                     0.126273                   0.050914
#   ..                         ...                        ...
#   92                    0.087066                   0.144684
#   93                    0.090616                   0.145230
#   94                    0.102685                   0.144553
#   95                    0.093598                   0.146920
#   96                    0.098667                   0.146452
#
#   [97 rows x 5 columns],
#   'LO3':           run_name  perturbation_epoch  delta_neural_alignment  \
#   0    training_run1                   1               -0.000238
#   1    training_run2                   2                0.011898
#   2    training_run3                   3                0.021517
#   3    training_run4                   4                0.028285
#   4    training_run5                   5                0.023729
#   ..             ...                 ...                     ...
#   92  training_run94                  94               -0.067028
#   93  training_run95                  95               -0.066980
#   94  training_run96                  96               -0.051584
#   95  training_run97                  97               -0.061489
#   96  training_run98                  98               -0.065745
#
#       perturbed_neural_alignment  baseline_neural_alignment
#   0                     0.078712                   0.078950
#   1                     0.064272                   0.052374
#   2                     0.074511                   0.052994
#   3                     0.082470                   0.054185
#   4                     0.081488                   0.057758
#   ..                         ...                        ...
#   92                    0.036868                   0.103896
#   93                    0.037019                   0.103999
#   94                    0.052321                   0.103905
#   95                    0.042320                   0.103809
#   96                    0.038713                   0.104458
#
#   [97 rows x 5 columns],
#   'V1':           run_name  perturbation_epoch  delta_neural_alignment  \
#   0    training_run1                   1               -0.009195
#   1    training_run2                   2                0.011540
#   2    training_run3                   3                0.011067
#   3    training_run4                   4                0.021117
#   4    training_run5                   5                0.026244
#   ..             ...                 ...                     ...
#   92  training_run94                  94               -0.023665
#   93  training_run95                  95               -0.028168
#   94  training_run96                  96               -0.021656
#   95  training_run97                  97               -0.022242
#   96  training_run98                  98               -0.031044
#
#       perturbed_neural_alignment  baseline_neural_alignment
#   0                    -0.002529                   0.006666
#   1                     0.003353                  -0.008187
#   2                    -0.000050                  -0.011117
#   3                     0.008980                  -0.012136
#   4                     0.011843                  -0.014402
#   ..                         ...                        ...
#   92                   -0.017154                   0.006511
#   93                   -0.022972                   0.005196
#   94                   -0.014609                   0.007046
#   95                   -0.016153                   0.006088
#   96                   -0.024423                   0.006621
#
#   [97 rows x 5 columns],
#   'V2':           run_name  perturbation_epoch  delta_neural_alignment  \
#   0    training_run1                   1               -0.005905
#   1    training_run2                   2                0.011751
#   2    training_run3                   3                0.009564
#   3    training_run4                   4                0.018063
#   4    training_run5                   5                0.021817
#   ..             ...                 ...                     ...
#   92  training_run94                  94               -0.019095
#   93  training_run95                  95               -0.022797
#   94  training_run96                  96               -0.017428
#   95  training_run97                  97               -0.020309
#   96  training_run98                  98               -0.025123
#
#       perturbed_neural_alignment  baseline_neural_alignment
#   0                    -0.000825                   0.005080
#   1                     0.000764                  -0.010987
#   2                    -0.001329                  -0.010893
#   3                     0.007643                  -0.010420
#   4                     0.010011                  -0.011806
#   ..                         ...                        ...
#   92                   -0.015602                   0.003493
#   93                   -0.020327                   0.002471
#   94                   -0.013569                   0.003859
#   95                   -0.017289                   0.003021
#   96                   -0.021536                   0.003587
#
#   [97 rows x 5 columns],
#   'V3':           run_name  perturbation_epoch  delta_neural_alignment  \
#   0    training_run1                   1               -0.006632
#   1    training_run2                   2                0.006472
#   2    training_run3                   3                0.001671
#   3    training_run4                   4                0.006960
#   4    training_run5                   5                0.007363
#   ..             ...                 ...                     ...
#   92  training_run94                  94               -0.029508
#   93  training_run95                  95               -0.032951
#   94  training_run96                  96               -0.024862
#   95  training_run97                  97               -0.029255
#   96  training_run98                  98               -0.036469
#
#       perturbed_neural_alignment  baseline_neural_alignment
#   0                    -0.016790                  -0.010158
#   1                    -0.011969                  -0.018442
#   2                    -0.012493                  -0.014165
#   3                    -0.003851                  -0.010810
#   4                    -0.002184                  -0.009547
#   ..                         ...                        ...
#   92                   -0.028897                   0.000610
#   93                   -0.033007                  -0.000057
#   94                   -0.023957                   0.000905
#   95                   -0.029505                  -0.000250
#   96                   -0.036063                   0.000407
#
#   [97 rows x 5 columns]})
