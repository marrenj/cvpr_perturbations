# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
import pandas as pd

REPO_NAME = "cvpr_perturbations"
repo_root = None
cwd = Path.cwd().resolve()
for path in (cwd, *cwd.parents):
    if path.name == REPO_NAME:
        repo_root = path
        break
if repo_root is None:
    raise RuntimeError(
        f"Unable to locate '{REPO_NAME}' in the current working tree; adjust REPO_NAME or run from project root."
    )
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))


from notebooks.utils.load_training_data import load_training_results
from notebooks.utils.single_epoch_dloss import plot_single_epoch_delta_test_loss

# %%
baseline_seed1_ba_results = load_training_results(
    Path("../../data/training_results/baseline/training_res_seed1.csv"),
    truncate_at_min_test_loss=True,
)


baseline_seed2_ba_results = load_training_results(
    Path("../../data/training_results/baseline/training_res_seed2.csv"),
    truncate_at_min_test_loss=True,
)


baseline_seed3_ba_results = load_training_results(
    Path("../../data/training_results/baseline/training_res_seed3.csv"),
    truncate_at_min_test_loss=True,
)

# %%
sweep_seed1_ba_results = load_training_results(
    Path("/home/wallacelab/teba/multimodal_brain_inspired/marren/temporal_dynamics_of_human_alignment/single_epoch_perturbation_sweeps/perturb_sweep_baselineseed1_perturbseed42"),
    multiple_files=True,
)

sweep_seed2_ba_results = load_training_results(
    Path("/home/wallacelab/teba/multimodal_brain_inspired/marren/temporal_dynamics_of_human_alignment/single_epoch_perturbation_sweeps/perturb_sweep_baselineseed2_perturbseed43"),
    multiple_files=True,
)

sweep_seed3_ba_results = load_training_results(
    Path("/home/wallacelab/teba/multimodal_brain_inspired/marren/temporal_dynamics_of_human_alignment/single_epoch_perturbation_sweeps/perturb_sweep_baselineseed3_perturbseed44"),
    multiple_files=True,
)

# %%
plot_single_epoch_delta_test_loss(baseline_seed1_ba_results, sweep_seed1_ba_results)
# Out:
# (<Axes: xlabel='Perturbation Epoch', ylabel='$\\Delta$ Test Loss'>,
#                run_name  perturbation_epoch  delta_test_loss  \
#  0    training_res_run1                   1         5.201120
#  1    training_res_run2                   2         2.849377
#  2    training_res_run3                   3         6.333081
#  3    training_res_run4                   4         9.139153
#  4    training_res_run5                   5        11.360021
#  ..                 ...                 ...              ...
#  93  training_res_run94                  94        63.498054
#  94  training_res_run95                  95        60.587195
#  95  training_res_run96                  96        66.547161
#  96  training_res_run97                  97        64.129440
#  97  training_res_run98                  98        60.483742
#
#      perturbed_test_loss  baseline_test_loss
#  0            119.468458          114.267337
#  1             94.159807           91.310430
#  2             91.204649           84.871568
#  3             89.515048           80.375895
#  4             87.807139           76.447118
#  ..                  ...                 ...
#  93            92.631251           29.133197
#  94            89.799713           29.212518
#  95            95.695314           29.148153
#  96            93.314413           29.184973
#  97            89.585051           29.101309
#
#  [98 rows x 5 columns])

# %%
plot_single_epoch_delta_test_loss(baseline_seed2_ba_results, sweep_seed2_ba_results)
# Out:
# (<Axes: xlabel='Perturbation Epoch', ylabel='$\\Delta$ Test Loss'>,
#                run_name  perturbation_epoch  delta_test_loss  \
#  0    training_res_run1                   1        -0.738980
#  1    training_res_run2                   2         2.566677
#  2    training_res_run3                   3         4.188189
#  3    training_res_run4                   4         4.369899
#  4    training_res_run5                   5         4.853732
#  5    training_res_run6                   6         5.575964
#  6    training_res_run7                   7         6.281197
#  7    training_res_run8                   8         7.585459
#  8    training_res_run9                   9         9.403572
#  9   training_res_run10                  10        11.712521
#  10  training_res_run11                  11        14.968319
#  11  training_res_run12                  12        16.965626
#  12  training_res_run13                  13        20.195267
#  13  training_res_run14                  14        21.685341
#  14  training_res_run15                  15        22.553017
#  15  training_res_run16                  16        23.937670
#  16  training_res_run17                  17        24.773817
#  17  training_res_run18                  18        25.262035
#  18  training_res_run19                  19        26.250577
#  19  training_res_run20                  20        29.188394
#  20  training_res_run21                  21        28.159966
#  21  training_res_run22                  22        30.320004
#  22  training_res_run23                  23        31.061760
#  23  training_res_run24                  24        29.933448
#  24  training_res_run25                  25        29.980877
#  25  training_res_run26                  26        35.187680
#  26  training_res_run27                  27        35.195510
#  27  training_res_run28                  28        37.731111
#  28  training_res_run29                  29        35.263024
#  29  training_res_run30                  30        38.708492
#  30  training_res_run31                  31        38.287500
#  31  training_res_run32                  32        37.040177
#  32  training_res_run33                  33        38.023392
#  33  training_res_run34                  34        38.238504
#  34  training_res_run35                  35        37.327639
#  35  training_res_run36                  36        41.342156
#  36  training_res_run37                  37        35.481152
#  37  training_res_run38                  38        43.191693
#  38  training_res_run39                  39        41.052901
#  39  training_res_run40                  40        42.808584
#  40  training_res_run41                  41        40.620930
#  41  training_res_run44                  44        40.080242
#  42  training_res_run47                  47        47.032366
#  43  training_res_run50                  50        45.589909
#  44  training_res_run53                  53        42.354647
#  45  training_res_run56                  56        44.492985
#  46  training_res_run59                  59        44.812936
#  47  training_res_run62                  62        40.758123
#  48  training_res_run65                  65        48.186358
#  49  training_res_run68                  68        47.952283
#  50  training_res_run71                  71        49.944201
#  51  training_res_run74                  74        49.150488
#  52  training_res_run77                  77        47.470154
#  53  training_res_run80                  80        40.193602
#  54  training_res_run83                  83        49.534423
#  55  training_res_run86                  86        47.368078
#  56  training_res_run89                  89        50.535363
#  57  training_res_run92                  92        51.231035
#
#      perturbed_test_loss  baseline_test_loss
#  0            118.424497          119.163477
#  1             95.780036           93.213360
#  2             90.582209           86.394020
#  3             86.297355           81.927456
#  4             82.722304           77.868572
#  5             79.979857           74.403894
#  6             78.060536           71.779339
#  7             76.725223           69.139764
#  8             75.301716           65.898144
#  9             73.512514           61.799993
#  10            72.014170           57.045852
#  11            70.696252           53.730625
#  12            71.662320           51.467052
#  13            71.328594           49.643253
#  14            70.511758           47.958740
#  15            70.558419           46.620749
#  16            70.227443           45.453626
#  17            69.511944           44.249909
#  18            69.462198           43.211621
#  19            71.510731           42.322337
#  20            69.636074           41.476108
#  21            71.112422           40.792418
#  22            71.078153           40.016393
#  23            69.292033           39.358585
#  24            68.682373           38.701497
#  25            73.346423           38.158743
#  26            72.842056           37.646547
#  27            74.898357           37.167246
#  28            71.966243           36.703220
#  29            74.982842           36.274350
#  30            74.173966           35.886466
#  31            72.695749           35.655571
#  32            73.405837           35.382444
#  33            73.357786           35.119282
#  34            72.077503           34.749864
#  35            75.835133           34.492977
#  36            69.755344           34.274191
#  37            77.214706           34.023013
#  38            74.907569           33.854668
#  39            76.442345           33.633761
#  40            74.084412           33.463482
#  41            73.094716           33.014473
#  42            79.664164           32.631797
#  43            77.764073           32.174164
#  44            74.171376           31.816728
#  45            76.092021           31.599037
#  46            76.116042           31.303105
#  47            71.928170           31.170047
#  48            79.207161           31.020803
#  49            78.706996           30.754713
#  50            80.613635           30.669434
#  51            79.729513           30.579025
#  52            77.992484           30.522330
#  53            70.632379           30.438776
#  54            79.946612           30.412188
#  55            77.656378           30.288300
#  56            80.803109           30.267746
#  57            81.475357           30.244321  )

# %%
plot_single_epoch_delta_test_loss(baseline_seed3_ba_results, sweep_seed3_ba_results)
# Out:
# (<Axes: xlabel='Perturbation Epoch', ylabel='$\\Delta$ Test Loss'>,
#                 run_name  perturbation_epoch  delta_test_loss  \
#  0     training_res_run1                   1        -1.430007
#  1     training_res_run2                   2         2.925778
#  2     training_res_run3                   3         5.890288
#  3     training_res_run4                   4         8.908374
#  4     training_res_run5                   5        10.603921
#  ..                  ...                 ...              ...
#  56   training_res_run89                  89        63.058663
#  57   training_res_run92                  92        60.601659
#  58   training_res_run95                  95        67.557569
#  59   training_res_run98                  98        66.112119
#  60  training_res_run101                 101        67.153400
#
#      perturbed_test_loss  baseline_test_loss
#  0            118.569331          119.999338
#  1             95.613692           92.687914
#  2             92.544762           86.654473
#  3             91.156940           82.248567
#  4             88.815838           78.211917
#  ..                  ...                 ...
#  56            92.291927           29.233264
#  57            89.865031           29.263372
#  58            96.759187           29.201618
#  59            95.350755           29.238636
#  60            96.365438           29.212037
#
#  [61 rows x 5 columns])
